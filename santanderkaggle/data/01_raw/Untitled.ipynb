# %%
import pandas as pd

# %%
#get params
id_columns = "ID"


features = pd.read_csv('C:\\Users\\Bruno\\Desktop\\git\\ModelingMLKedroPipeline\\santanderkaggle\\data/03_models/feature_to_keep.csv')
df = pd.read_csv("test.csv")
# Convert the DataFrame to a list
features = features['0'].values.tolist()

# Create a boolean mask that checks if each column name is in 'features_set'
column_mask = df.columns.isin(features)

# %%
# Use the boolean mask to select the desired columns
df_validation = df.set_index(id_columns)

# %%
# Use the boolean mask to select the desired columns
df_validation[features]
# Out:
#         var3  var15  imp_ent_var16_ult1  imp_op_var39_comer_ult1  \
# ID
# 2          2     32                 0.0                      0.0
# 5          2     35                 0.0                      0.0
# 6          2     23                 0.0                      0.0
# 7          2     24                 0.0                      0.0
# 9          2     23                 0.0                      0.0
# ...      ...    ...                 ...                      ...
# 151831     2     23                 0.0                      0.0
# 151832     2     26                 0.0                      0.0
# 151833     2     24                 0.0                      0.0
# 151834     2     40                 0.0                      0.0
# 151837     2     23                 0.0                      0.0
#
#         imp_op_var40_efect_ult1  imp_op_var41_efect_ult1  ind_var5_0  \
# ID
# 2                           0.0                      0.0           1
# ...
